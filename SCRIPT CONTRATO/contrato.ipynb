# %%
import requests
import json
import pandas as pd
from IPython.display import display
import time

# %%
token = "eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUEkgZGUgSW50ZWdyYcOnw6NvIExvZ3VzIiwic3ViIjoiNjIyNjUxMDgzODMiLCJpYXQiOjE3MDgzNTE4NDIsImV4cCI6MTcwODQzODI0Mn0.WvVPI3FfvpNpuI2y9Wz5df9zRIENxiIEm9RxWIGblBU"

def getContratoNumeroAutomatico(exercicio: int, pagina: int, totalRegistroPagina=10):
    """
    Função para organizar a estrutura do JSON e retornar o número do contrato.
    """
    try:
        url = f"https://tesouro.sefaz.pi.gov.br/siafe-api/contrato/{exercicio}/{pagina}/{totalRegistroPagina}"
        headers = {"Content-Type": "application/json", "Authorization": token}
        data = {
            "numeroContrato": "",
            "nomeContrato": "",
            "numeroOriginal": "",
        }
        data = json.dumps(data)

        resposta = requests.post(url=url, headers=headers, data=data)
        resposta.raise_for_status()  # Lança uma exceção se o status code não for bem-sucedido

        if resposta.status_code == 200:
            resposta_dado = resposta.json()
            
            # Criar listas vazias para armazenar os números dos contratos
            numeros_contratos = []
            
            # Iterar sobre os registros do JSON
            for registro in resposta_dado.get("registros", []):
                numeroContrato = registro.get("numeroContrato")
                numeros_contratos.append(numeroContrato)
                
            # Retorna a lista de números de contrato
            return numeros_contratos

    except requests.exceptions.HTTPError as err:
        print(f"Erro HTTP: {err}")
    except Exception as e:
        print(f"Ocorreu um erro durante a organização dos dados: {e}")

# %%
#RODAR ENQUANTO ESTIVER PAGINA 

token = "eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUEkgZGUgSW50ZWdyYcOnw6NvIExvZ3VzIiwic3ViIjoiNjIyNjUxMDgzODMiLCJpYXQiOjE3MDgzNTE4NDIsImV4cCI6MTcwODQzODI0Mn0.WvVPI3FfvpNpuI2y9Wz5df9zRIENxiIEm9RxWIGblBU"

def getContratoNumeroAutomatico(exercicio: int, pagina: int, totalRegistroPagina=10):
    """
    Função para organizar a estrutura do JSON e salvar os dados em um arquivo Excel.
    """
    try:
        while True:  # Executa continuamente enquanto possuiProximaPagina for True
            url = f"https://tesouro.sefaz.pi.gov.br/siafe-api/contrato/{exercicio}/{pagina}/{totalRegistroPagina}"
            headers = {"Content-Type": "application/json", "Authorization": token}
            data = {
                "numeroContrato": "",
                "nomeContrato": "",
                "numeroOriginal": "",
            }
            data = json.dumps(data)

            resposta = requests.post(url=url, headers=headers, data=data)
            resposta.raise_for_status()  # Lança uma exceção se o status code não for bem-sucedido

            if resposta.status_code == 200:
                resposta_dado = resposta.json()

                # Criar listas vazias para armazenar os dados dos registros pai e dos filhos
                registros_pai = []

                possuiProximaPagina = resposta_dado.get("possuiProximaPagina")
                print(possuiProximaPagina)

                # Iterar sobre os registros do JSON
                for registro in resposta_dado.get("registros", []):
                    numeroContrato = registro.get("numeroContrato")

                    # Extrair os dados dos registros pai
                    registro_pai = {
                        "numeroContrato": numeroContrato,
                    }
                    registros_pai.append(registro_pai)

                # Criar DataFrames a partir das listas de dados
                df_NumeroAutomatico = pd.DataFrame(registros_pai)

                # Exibir o DataFrame dos itens filhos
                display(df_NumeroAutomatico)

                if not possuiProximaPagina:
                    break  # Se não houver próxima página, saia do loop

                pagina += 1  # Avança para a próxima página

                # Aguarda um intervalo antes de fazer a próxima solicitação (opcional)
                time.sleep(1)

    except requests.exceptions.HTTPError as err:
        print(f"Erro HTTP: {err}")
    except Exception as e:
        print(f"Ocorreu um erro durante a organização dos dados: {e}")

# %%
token = "eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUEkgZGUgSW50ZWdyYcOnw6NvIExvZ3VzIiwic3ViIjoiNjIyNjUxMDgzODMiLCJpYXQiOjE3MDg0Mjk3ODIsImV4cCI6MTcwODUxNjE4Mn0.5_XJJJYF_rQUSTDkkrW_tPVspBpTQ-5EBIH7pbc1Xco"

def getContratoNumeroAutomatico(exercicio: int, pagina: int, totalRegistroPagina=10):
    """
    Função para organizar a estrutura do JSON e retornar o número do contrato.
    """
    try:
        url = f"https://tesouro.sefaz.pi.gov.br/siafe-api/contrato/{exercicio}/{pagina}/{totalRegistroPagina}"
        headers = {"Content-Type": "application/json", "Authorization": token}
        data = {
            "numeroContrato": "",
            "nomeContrato": "",
            "numeroOriginal": "",
        }
        data = json.dumps(data)

        resposta = requests.post(url=url, headers=headers, data=data)
        resposta.raise_for_status()  # Lança uma exceção se o status code não for bem-sucedido

        if resposta.status_code == 200:
            resposta_dado = resposta.json()
            
            # Criar listas vazias para armazenar os números dos contratos
            numeros_contratos = []
            
            # Iterar sobre os registros do JSON
            for registro in resposta_dado.get("registros", []):
                numeroContrato = registro.get("numeroContrato")
                numeros_contratos.append(numeroContrato)
                
            # Retorna a lista de números de contrato
            return numeros_contratos

    except requests.exceptions.HTTPError as err:
        print(f"Erro HTTP: {err}")
    except Exception as e:
        print(f"Ocorreu um erro durante a organização dos dados: {e}")

NumeroAutomatico = getContratoNumeroAutomatico(exercicio=2024, pagina=1)

def getContrato(exercicio: int, NumeroAutomatico=NumeroAutomatico):
    """
    Função para organizar a estrutura do JSON e salvar os dados em um arquivo Excel.
    """
    try:
        url = f"https://tesouro.sefaz.pi.gov.br/siafe-api//{exercicio}/{NumeroAutomatico}"
        headers = {"Content-Type": "application/json", "Authorization": token}
        data = {
            
        }
        data = json.dumps(data)

        resposta = requests.post(url=url, headers=headers, data=data)
        resposta.raise_for_status()  # Lança uma exceção se o status code não for bem-sucedido

        if resposta.status_code == 200:
            resposta_dado = resposta.json()
            
            # Criar listas vazias para armazenar os dados dos registros pai e dos filhos
            dadosContrato = []
            

            # Iterar sobre os registros do JSON
            for registro in resposta_dado.get("", []):
                
                
                # Extrair os dados dos registros pai
                dadosContrato = {
                    "numeroContrato": numeroContrato,
                    "": registro.get(""),
                    
                }
                dadosContrato.append(dadosContrato)
                
                

            # Criar DataFrames a partir das listas de dados
            dadosContrato = pd.DataFrame(dadosContrato)
            
            
            # Exibir o DataFrame dos itens filhos
            display(dadosContrato)

    except requests.exceptions.HTTPError as err:
        print(f"Erro HTTP: {err}")
    except Exception as e:
        print(f"Ocorreu um erro durante a organização dos dados: {e}")

# %%
token = "eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUEkgZGUgSW50ZWdyYcOnw6NvIExvZ3VzIiwic3ViIjoiNjIyNjUxMDgzODMiLCJpYXQiOjE3MDg0Mjk3ODIsImV4cCI6MTcwODUxNjE4Mn0.5_XJJJYF_rQUSTDkkrW_tPVspBpTQ-5EBIH7pbc1Xco"

def getContratoNumeroAutomatico(exercicio: int, pagina: int, totalRegistroPagina=10):
    """
    Função para obter os números dos contratos.
    """
    try:
        url = f"https://tesouro.sefaz.pi.gov.br/siafe-api/contrato/{exercicio}/{pagina}/{totalRegistroPagina}"
        headers = {"Content-Type": "application/json", "Authorization": token}
        data = {
            "numeroContrato": "",
            "nomeContrato": "",
            "numeroOriginal": "",
        }
        data = json.dumps(data)

        resposta = requests.post(url=url, headers=headers, data=data)
        resposta.raise_for_status()  # Raises an HTTPError if the status is not successful

        if resposta.status_code == 200:
            resposta_dado = resposta.json()
            numeros_contratos = [registro.get("numeroContrato") for registro in resposta_dado.get("registros", [])]
            return numeros_contratos

    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error: {err}")
    except Exception as e:
        print(f"An error occurred while organizing data: {e}")

NumeroAutomatico = getContratoNumeroAutomatico(exercicio=2024, pagina=1)

def getContrato(exercicio: int, numeros_contratos):
    """
    Função para obter os dados dos contratos e salvar em um DataFrame e Excel.
    """
    try:
        dadosContratos = []

        for numeroContrato in numeros_contratos:
            url = f"https://tesouro.sefaz.pi.gov.br/siafe-api/{exercicio}/{numeroContrato}"
            headers = {"Content-Type": "application/json", "Authorization": token}
            data = {}

            resposta = requests.post(url=url, headers=headers, data=json.dumps(data))
            resposta.raise_for_status()  # Raises an HTTPError if the status is not successful

            if resposta.status_code == 200:
                resposta_dado = resposta.json()
                
                # Append contrato data
                dadosContratos.append({
                    "numeroContrato": numeroContrato,
                    "data": resposta_dado.get("data", None),
                    # Add more fields as needed
                })

        # Create DataFrame
        df_contratos = pd.DataFrame(dadosContratos)
        
        display(df_contratos)
        
        # Save to Excel
        #df_contratos.to_excel("contratos.xlsx", index=False)
        
        return df_contratos

    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error: {err}")
    except Exception as e:
        print(f"An error occurred while organizing data: {e}")

# %%
NumeroAutomatico = getContratoNumeroAutomatico(exercicio=2024, pagina=1)
display(NumeroAutomatico)
# Out:
# ['17000001',
#  '17000002',
#  '17000003',
#  '17000004',
#  '17000005',
#  '17000006',
#  '17000007',
#  '17000008',
#  '17000009',
#  '17000010']

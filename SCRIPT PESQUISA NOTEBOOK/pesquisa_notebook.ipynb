# %%
import requests
from bs4 import BeautifulSoup
from fpdf import FPDF
import pandas as pd
from IPython.display import display

# %%
def search_notebook(processor, generation, storage, ram, os, max_price, store):
    if store == "Amazon":
        url = f"https://www.amazon.com.br/s?k=notebook+{processor}+{generation}+{storage}+{ram}GB+{os}&max-price={max_price}&_encoding=UTF8"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        notebooks = []

        for item in soup.find_all("div", class_="s-result-item"):
            try:
                title = item.find("span", class_="a-size-medium").text.strip()
                price = float(item.find("span", class_="a-price-whole").text.replace(".", "").replace(",", "."))
                link = "https://www.amazon.com.br" + item.find("a", class_="a-link-normal").get("href")

                notebooks.append({"title": title, "price": price, "link": link})
            except:
                pass

    # Adicione mais lojas aqui usando estruturas condicionais semelhantes

    return notebooks

def generate_pdf(notebooks):
    pdf = FPDF()
    pdf.add_page()
    pdf.set_font("Arial", size=12)

    for notebook in notebooks:
        pdf.cell(200, 10, txt=f"Nome: {notebook['title']}", ln=True)
        pdf.cell(200, 10, txt=f"Preço: R$ {notebook['price']:.2f}", ln=True)
        pdf.cell(200, 10, txt=f"Link: {notebook['link']}", ln=True)
        pdf.cell(200, 10, txt="", ln=True)  # Espaço entre os notebooks

    pdf.output("notebooks.pdf")

# %%
if __name__ == "__main__":
    processor_i5 = "i5"
    generation_10 = "10ª"
    storage_256 = "256GB"
    ram_8 = "8"
    os_windows = "Windows"
    os_linux = "Linux"
    max_price = 2200.00

    stores = ["Amazon"]  # Adicione mais lojas aqui

    notebooks = []

    for store in stores:
        notebooks += search_notebook(processor_i5, generation_10, storage_256, ram_8, os_windows, max_price, store)
        notebooks += search_notebook(processor_i5, generation_10, storage_256, ram_8, os_linux, max_price, store)

    #generate_pdf(notebooks)
    
    df = pd.DataFrame(notebooks, columns=['Modelo', 'Processador', 'Armazenamento', 'RAM', 'Sistema Operacional', 'Preço', 'Loja'])
    
    
    display(notebooks)
# Out:
# []

# %%
import requests
import pandas as pd

# Configurações da API Custom Search
API_KEY = "AIzaSyDbcp2QWm2Rqe2SaMZkD9hIKBKh1pzdaTQ"
SEARCH_ENGINE_ID = "a5173f1cf87d947e7"

# Função para buscar notebooks
def search_notebooks(query):
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    response = requests.get(url)
    data = response.json()
    return data.get('items', [])

# Função para filtrar notebooks por preço
def filter_notebooks(notebooks, max_price):
    filtered_notebooks = []
    for notebook in notebooks:
        price = notebook.get('pagemap', {}).get('offer', [{}])[0].get('price', '').replace('$', '').replace(',', '')
        if price.isdigit() and float(price) <= max_price:
            filtered_notebooks.append({
                'title': notebook.get('title', ''),
                'link': notebook.get('link', ''),
                'price': float(price)
            })
    return filtered_notebooks

# Função para encontrar o notebook mais barato
def find_cheapest_notebook(notebooks):
    if notebooks:
        cheapest = min(notebooks, key=lambda x: x['price'])
        return cheapest
    return None

# Função para relatar notebooks encontrados
def report_notebooks(notebooks, query):
    print(f"Resultados para '{query}':")
    for notebook in notebooks:
        print(f"Nome: {notebook['title']}")
        print(f"Preço: ${notebook['price']:.2f}")
        print(f"Link: {notebook['link']}")
        print()

# Pesquisa por um notebook i5 de 10ª geração com 256 SSD, 8 GB de RAM e sistema Linux/Windows até $9200
query_i5 = "notebook i5 10th generation 256 ssd 8gb ram Linux OR Windows"
notebooks_i5 = search_notebooks(query_i5)
filtered_notebooks_i5 = filter_notebooks(notebooks_i5, 9200)
cheapest_i5 = find_cheapest_notebook(filtered_notebooks_i5)
report_notebooks(filtered_notebooks_i5, query_i5)

if cheapest_i5:
    print("O notebook mais barato encontrado:")
    print(f"Nome: {cheapest_i5['title']}")
    print(f"Preço: ${cheapest_i5['price']:.2f}")
    print(f"Link: {cheapest_i5['link']}")
    print()

# Pesquisa por um notebook i3 de 11ª geração com 256 SSD, 8 GB de RAM e sistema Linux/Windows até $9200
query_i3 = "notebook i3 11th generation 256 ssd 8gb ram Linux OR Windows"
notebooks_i3 = search_notebooks(query_i3)
filtered_notebooks_i3 = filter_notebooks(notebooks_i3, 1)
cheapest_i3 = find_cheapest_notebook(filtered_notebooks_i3)
report_notebooks(filtered_notebooks_i3, query_i3)

# Extrair campos relevantes
dados_formatados = [{'title': item['title'], 'link': item['link'], 'snippet': item['snippet'], 'formattedUrl': item['formattedUrl']} for item in notebooks_i3]

# Criar DataFrame
df = pd.DataFrame(dados_formatados)

# Exibir DataFrame
display(df)

if cheapest_i3:
    print("O notebook mais barato encontrado:")
    print(f"Nome: {cheapest_i3['title']}")
    print(f"Preço: ${cheapest_i3['price']:.2f}")
    print(f"Link: {cheapest_i3['link']}")
    print()
# Out:
# Resultados para 'notebook i5 10th generation 256 ssd 8gb ram Linux OR Windows':
# Resultados para 'notebook i3 11th generation 256 ssd 8gb ram Linux OR Windows':
#                                                title  \
# 0  Lenovo 2022 Newest Ideapad 3 Laptop, 15.6" HD ...
# 1  Is the i3 11th generation good for programming...
# 2  HP New 2022 17.3" FHD IPS Display, 11th Gen In...
# 3  Real Life Experience with Surface Pro 7+ 11th ...
# 4  Lenovo 15 Laptop, 11th Generation Intel Core i...
# 5  HP 17 Laptop, 17.3” HD+ Display, 11th Gen Inte...
# 6  HP 15-dw Laptop Intel Core i3-1115G4 8GB 256GB...
# 7  Lenovo Ideapad 3i 15.6" HD Touch Laptop Core i...
# 8  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...
# 9                     Laptops with 8GB Ram 256GB SSD
#
#                                                 link  \
# 0  https://www.amazon.com/Lenovo-Ideapad-Touchscr...
# 1  https://www.quora.com/Is-the-i3-11th-generatio...
# 2  https://www.amazon.com/HP-Display-i3-1115G4-Wi...
# 3  https://www.reddit.com/r/Surface/comments/svos...
# 4  https://www.amazon.com/Lenovo-Generation-i3-11...
# 5  https://www.walmart.com/ip/HP-17-Laptop-17-3-H...
# 6  https://www.amazon.com/HP-15-dw-Laptop-Intel-i...
# 7  https://www.bestbuy.com/site/lenovo-ideapad-3i...
# 8  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...
# 9  https://www.hp.com/us-en/shop/vwa/8gb-ram-256g...
#
#                                              snippet  \
# 0  Amazon.com: Lenovo 2022 Newest Ideapad 3 Lapto...
# 1  Dec 3, 2022 ... Is Core i3, 11th Gen, 8GB RAM,...
# 2  Amazon.com: HP New 2022 17.3" FHD IPS Display,...
# 3  Feb 18, 2022 ... Not to mention, I predict tha...
# 4  Amazon.com: Lenovo 15 Laptop, 11th Generation ...
# 5  Arrives by Tue, Apr 2 Buy HP 17 Laptop, 17.3” ...
# 6  Hard Disk Size. 256 GB ; CPU Model. Core I3 11...
# 7  Shop Lenovo Ideapad 3i 15.6" HD Touch Laptop C...
# 8  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...
# 9  HP Laptop 17t-cn400, 17.3". Windows 11 HomeInt...
#
#                                         formattedUrl
# 0  https://www.amazon.com/Lenovo-Ideapad...i3-100...
# 1  https://www.quora.com/Is-the-i3-11th-generatio...
# 2  https://www.amazon.com/HP-Display-i3...Windows...
# 3  https://www.reddit.com/.../real_life_experienc...
# 4  https://www.amazon.com/Lenovo-Generation-i3......
# 5  https://www.walmart.com/...11th...i3...8GB-RAM...
# 6  https://www.amazon.com/HP-15-dw-Laptop-Intel-i...
# 7  https://www.bestbuy.com/site/...3i...i3...8gb....
# 8  https://www.amazon.in/HP-i3-1115G4-Micro-Edge-...
# 9  https://www.hp.com/us-en/shop/.../8gb-ram-256g...
